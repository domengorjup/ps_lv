# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sdg1x import SDG1X

# %% [markdown]
# Connect to SDG1X signal generator:

# %%
sg = SDG1X()
# Out:
# 2025-04-08 12:36:30,961 - INFO - Connected to Siglent Technologies,SDG1032X,SDG1XDDD7R6585,1.01.01.33R3

# %% [markdown]
# Example channel output settings:

# %%
# Set example waveform on channel 1
sg.set_basic_wave(
    channel=1,
    frequency=15.22,
    amplitude=1.11,
    offset=1.2,
    phase=90,
    waveform='RAMP',
    output=False
    )

# Set example waveform on channel 2
sg.set_basic_wave(
    channel=2,
    frequency=5.01,
    amplitude=1.11,
    offset=1.2,
    phase=0,
    waveform='SINE',
    output=True
    )
# Out:
# 2025-04-08 12:36:32,193 - INFO - instrument channel settings:
# C1:BSWV WVTP,RAMP,FRQ,15.22HZ,PERI,0.065703S,AMP,1.11V,AMPVRMS,0.320439Vrms,OFST,1.2V,HLEV,1.755V,LLEV,0.645V,PHSE,90,SYM,50
#
# 2025-04-08 12:36:32,392 - INFO - instrument channel settings:
# C2:BSWV WVTP,SINE,FRQ,5.01HZ,PERI,0.199601S,AMP,1.11V,AMPVRMS,0.392385Vrms,OFST,1.2V,HLEV,1.755V,LLEV,0.645V,PHSE,0
