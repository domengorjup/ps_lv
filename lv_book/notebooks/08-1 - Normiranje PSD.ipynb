# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import csd

# %%
f = 5
T = 1
fs = 100
t = np.arange(fs*T) / fs
x = np.sin(2*np.pi*f*t) + np.random.randn(len(t))*0.5

# %%
X = np.fft.fft(x) / len(x)
f = np.fft.fftfreq(len(x), 1/fs)

# %%
f_, PSD_scipy = csd(x, x, fs, scaling='density', window=np.ones_like(a), return_onesided=False)

# %%
PSD = np.abs(X)**2 * T

# %%
plt.plot(f_, np.abs(PSD_scipy))
plt.plot(f, np.abs(PSD), '--')
